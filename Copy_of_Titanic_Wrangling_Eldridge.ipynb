# %% [markdown]
# # Titanic Wrangling
#
# In this practice activity you'll continue to work with the titanic dataset in ways that flex what you've learned about both data wrangling and data visualization.

# %%
# Import the titanic dataset here
import pandas as pd

data_dir = "https://dlsun.github.io/pods/data/"
df_titanic = pd.read_csv(data_dir + "titanic.csv")

# %% [markdown]
# ## 1. Filter the data to include passengers only. Calculate the joint distribution (cross-tab) between a passenger's class and where they embarked.

# %%
df_titanic["class"].unique()

df_titanic["type"] = df_titanic["class"].map({
    "1st": "passenger",
    "2nd": "passenger",
    "3rd": "passenger",
    "victualling crew": "crew",
    "engineering crew": "crew",
    "deck crew": "crew",
    "restaurant staff": "crew"
})

# %%
where_pass = df_titanic['type'] == 'passenger'
df_pass = df_titanic[where_pass]

# %%
pd.crosstab(df_pass["embarked"], df_pass["class"], normalize = True)
# Out:
# class          1st       2nd       3rd
# embarked
# B         0.002278  0.004556  0.000000
# C         0.108580  0.019742  0.077449
# Q         0.002278  0.005315  0.085801
# S         0.132878  0.186029  0.375095

# %% [markdown]
# ## 2. Using the joint distribution that calculated above, calculate the following:
#
# * the conditional distribution of their class given where they embarked
# * the conditional distribution of where they embarked given their class
#
# Use the conditional distributions that you calculate to answer the following quesitons:
#
# * What proportion of 3rd class passengers embarked at Southampton?
# * What proportion of Southampton passengers were in 3rd class?

# %%
joint_ec = pd.crosstab(df_pass["embarked"], df_pass["class"], normalize = True)

df_third = df_pass[df_pass["class"] == "3rd"]
df_third['embarked'].value_counts(normalize = True)
# Out:
# embarked
# S    0.696756
# Q    0.159379
# C    0.143865
# Name: proportion, dtype: float64

# %%
joint_ec
marginal_class = joint_ec.sum(axis = 0)
conditional_ec = joint_ec.divide(marginal_class)

conditional_ec["embarked"] = conditional_ec.index
conditional_ec
# Out:
# class          1st       2nd       3rd embarked
# embarked
# B         0.009259  0.021127  0.000000        B
# C         0.441358  0.091549  0.143865        C
# Q         0.009259  0.024648  0.159379        Q
# S         0.540123  0.862676  0.696756        S

# %% [markdown]
# Proportion of 3rd class at Southhampton: 69.67%(0.6967)
# Don't know what proportion of Southhampton passengers were 3rd class from this dist.

# %% [markdown]
# 3. Make a visualization showing the distribution of a passenger's class, given where they embarked.
#
# Discuss the pros and cons of using this visualization versus the distributions you calculated before, to answer the previous questions.

# %%
joint_ec = pd.crosstab(df_titanic["embarked"], df_titanic["class"])

marginal_class = joint_ec.sum(axis=1)

conditional_ec = joint_ec.divide(marginal_class, axis=0)
conditional_ec
# Out:
# class          1st       2nd       3rd  deck crew  engineering crew  \
# embarked
# B         0.015228  0.030457  0.000000   0.116751          0.218274
# C         0.527675  0.095941  0.376384   0.000000          0.000000
# Q         0.024390  0.056911  0.918699   0.000000          0.000000
# S         0.108292  0.151609  0.305693   0.026609          0.173886
#
# class     restaurant staff  victualling crew
# embarked
# B                 0.000000          0.619289
# C                 0.000000          0.000000
# Q                 0.000000          0.000000
# S                 0.042698          0.191213

# %% [markdown]
# This visualization provides a more comprehensive report than the one above, which means it would be better for answering certain questions.
